# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_directorio = '/content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/'

# leemos la base de datos SAE previamente guardada
path_postulantes_2018 = path_directorio+'MINEDUC_SAE/Postulantes 2018.csv'
path_postulaciones_2018 = path_directorio+'MINEDUC_SAE/Postulaciones 2018.csv'
path_postulantes_2019 = path_directorio+'MINEDUC_SAE/Postulantes 2019.csv'
path_postulaciones_2019 = path_directorio+'MINEDUC_SAE/Postulaciones 2019.csv'
path_postulantes_2020 = path_directorio+'MINEDUC_SAE/Postulantes 2020.csv'
path_postulaciones_2020 = path_directorio+'MINEDUC_SAE/Postulaciones 2020.csv'
path_postulantes_2021 = path_directorio+'MINEDUC_SAE/Postulantes 2021.csv'
path_postulaciones_2021 = path_directorio+'MINEDUC_SAE/Postulaciones 2021.csv'

df_postulantes_2018  = pd.read_csv(path_postulantes_2018,sep=';',low_memory=False,encoding="ISO-8859-1")
df_postulaciones_2018 = pd.read_csv(path_postulaciones_2018,sep=';',low_memory=False,encoding="ISO-8859-1")
df_postulantes_2019  = pd.read_csv(path_postulantes_2019,sep=';',low_memory=False,encoding="ISO-8859-1")
df_postulaciones_2019 = pd.read_csv(path_postulaciones_2019,sep=';',low_memory=False,encoding="ISO-8859-1")
df_postulantes_2020  = pd.read_csv(path_postulantes_2020,sep=';',low_memory=False,encoding="ISO-8859-1")
df_postulaciones_2020 = pd.read_csv(path_postulaciones_2020,sep=';',low_memory=False,encoding="ISO-8859-1")
df_postulantes_2021  = pd.read_csv(path_postulantes_2021,sep=';',low_memory=False,encoding="ISO-8859-1")
df_postulaciones_2021 = pd.read_csv(path_postulaciones_2021,sep=';',low_memory=False,encoding="ISO-8859-1")

# %%
# leemos los archivos de directorio

df_directorio_1oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_1oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_2oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_2oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_3oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_3oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_4oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_4oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_5oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_5oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_6oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_6oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_7oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_7oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_8oB  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_8oB.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_1oM  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_1oM.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_2oM  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_2oM.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_3oM  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_3oM.csv',sep=';',low_memory=False,encoding="ISO-8859-1")
df_directorio_4oM  = pd.read_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_4oM.csv',sep=';',low_memory=False,encoding="ISO-8859-1")

# %%
# Leemos la base de datos de directorio limpia, para poder hacer el match de solo los colegios
path_directorio2 = path_directorio+'Directorio_2021/Directorio_Oficial_EE_2021_CLEAN_30042024.csv'


df_directorio  = pd.read_csv(path_directorio2,sep=';',low_memory=False,encoding="ISO-8859-1")

# %%
df_directorio.head(5)
# Out:
#    AGNO  RBD  DGV_RBD                                            NOM_RBD MRUN  \
# 0  2021   97        3          INST. COM. DE IQUIQUE BALDOMERO WOLNITZKY
# 1  2021  103        1          ESC.EDUC.GRAL.BAS.Y DES.ART.VIOLETA PARRA
# 2  2021  107        4             LICEO LIBERT. GRAL.BERNARDO OÂ´HIGGINS
# 3  2021  108        2           LICEO POLITEC. JOSE GUTIERREZ DE LA FUEN
# 4  2021  109        0  COLEGIO DEPORTIVO TEC. PROF. ELENA DUVAUCHELLE...
#
#   RUT_SOSTENEDOR  P_JURIDICA  COD_REG_RBD NOM_REG_RBD_A  COD_PRO_RBD  ...  \
# 0       70938800           1            1          TPCA           11  ...
# 1       70938800           1            1          TPCA           11  ...
# 2       70938800           1            1          TPCA           11  ...
# 3       70938800           1            1          TPCA           11  ...
# 4       70938800           1            1          TPCA           11  ...
#
#    ENS_08 ENS_09  ENS_10 ENS_11  MATRICULA  ESTADO_ESTAB  ORI_RELIGIOSA  \
# ...

# %%
df_postulantes_2018.head(5)
# Out:
#    mrun  cod_nivel  es_mujer      lat_con_error      lon_con_error
# 0    48          1         1   -34,177737958914  -70,7157946495546
# 1   145          0         1  -36,9885914681132  -73,1524137527676
# 2   165          9         1  -32,4505045131111  -71,2325564894621
# 3   203          1         0   -38,711416059151  -72,6682150308778
# 4   244          3         0  -34,1822159167995  -70,7476901060171

# %%
agno2018 = np.ones(df_postulantes_2018.shape[0])*2018
agno2019 = np.ones(df_postulantes_2019.shape[0])*2019
agno2020 = np.ones(df_postulantes_2020.shape[0])*2020
agno2021 = np.ones(df_postulantes_2021.shape[0])*2021

df_postulantes_2018['AGNO'] = agno2018
df_postulantes_2019['AGNO'] = agno2019
df_postulantes_2020['AGNO'] = agno2020
df_postulantes_2021['AGNO'] = agno2021

# uniremos las 4 bases de datos del SAE.
df_postulantes = pd.concat([df_postulantes_2018, df_postulantes_2019,df_postulantes_2020, df_postulantes_2021])
df_postulaciones = pd.concat([df_postulaciones_2018, df_postulaciones_2019,df_postulaciones_2020, df_postulaciones_2021])
df_postulantes = df_postulantes.reset_index(drop=True)
df_postulantes
# Out:
#              mrun  cod_nivel  es_mujer      lat_con_error      lon_con_error  \
# 0              48          1         1   -34,177737958914  -70,7157946495546
# 1             145          0         1  -36,9885914681132  -73,1524137527676
# 2             165          9         1  -32,4505045131111  -71,2325564894621
# 3             203          1         0   -38,711416059151  -72,6682150308778
# 4             244          3         0  -34,1822159167995  -70,7476901060171
# ...           ...        ...       ...                ...                ...
# 1849777  26620085         -1         0        -23,6493461        -70,3914835
# 1849778  26620086          8         1        -33,4544225        -70,6509495
# 1849779  26620087          7         1        -33,5816101        -70,6702989
# 1849780  26620088          6         0        -33,4605683        -70,6733209
# 1849781  26620089          9         1        -33,4321082        -70,6578637
#
#            AGNO
# 0        2018.0
# ...

# %%
df_postulaciones = df_postulaciones.reset_index(drop=True)
df_postulaciones
# Out:
#              mrun  cod_nivel    rbd  preferencia_postulante  \
# 0              48          1   2151                       2
# 1              48          1  20364                       1
# 2             145          0   5005                       2
# 3             145          0  16770                       1
# 4             165          9  14416                       2
# ...           ...        ...    ...                     ...
# 6143264  26620089          9   8503                       5
# 6143265  26620089          9   8504                       3
# 6143266  26620089          9   8506                       2
# 6143267  26620089          9   8617                       6
# 6143268  26620089          9   8643                       4
#
#          prioridad_hermano  prioridad_hijo_funcionario  prioridad_exalumno
# 0                        0                           0                   0
# 1                        0                           0                   0
# ...

# %%
# ahora dejaremos solo los RBD contenidos en el dataframe directorio los demas los eliminaremos
index_rbd = []
for rbd in df_directorio['RBD']:
    out = df_postulaciones['rbd']==rbd
    index_rbd.extend(list(out.index[out]))

# este data frame contiene solo la informacion de los colegios contenidos en directorio, para la region y que esten e funcionamiento
df_postulaciones_clean = df_postulaciones.iloc[index_rbd]
df_postulaciones_clean = df_postulaciones_clean.reset_index(drop=True)
df_postulaciones_clean
# Out:
#              mrun  cod_nivel    rbd  preferencia_postulante  \
# 0            3684          9     97                       1
# 1           40261         11     97                       4
# 2           40261         11     97                       3
# 3          244136          9     97                       3
# 4          400578          9     97                       2
# ...           ...        ...    ...                     ...
# 5722016  15088767          1  31409                       1
# 5722017  14672260          7  31409                       1
# 5722018  17386569          7  31409                       1
# 5722019  12698657          1  31409                       1
# 5722020  20057428          7  31409                       2
#
#          prioridad_hermano  prioridad_hijo_funcionario  prioridad_exalumno
# 0                        0                           0                   0
# 1                        0                           0                   0
# ...

# %%
df_postulaciones_clean = df_postulaciones_clean.merge(df_postulantes)
df_postulaciones_clean
# Out:
#              mrun  cod_nivel    rbd  preferencia_postulante  \
# 0            3684          9     97                       1
# 1            3684          9    108                       3
# 2            3684          9    109                       4
# 3            3684          9    134                       5
# 4            3684          9  10901                       6
# ...           ...        ...    ...                     ...
# 5760595  19249421         11  31116                       1
# 5760596  22466476          9  31116                       2
# 5760597  26613325          9  31116                       2
# 5760598  17386569          7  31409                       1
# 5760599  12698657          1  31409                       1
#
#          prioridad_hermano  prioridad_hijo_funcionario  prioridad_exalumno  \
# 0                        0                           0                   0
# 1                        0                           0                   0
# ...

# %%
# ahora dejaremos solo los alumnos que postulen entre 1ro y 4to medio
mask = df_postulaciones_clean['cod_nivel']>=1
df_postulaciones_final =  df_postulaciones_clean[mask]
df_postulaciones_final = df_postulaciones_final.reset_index(drop=True)
df_postulaciones_final
# Out:
#              mrun  cod_nivel    rbd  preferencia_postulante  \
# 0            3684          9     97                       1
# 1            3684          9    108                       3
# 2            3684          9    109                       4
# 3            3684          9    134                       5
# 4            3684          9  10901                       6
# ...           ...        ...    ...                     ...
# 3851838  19249421         11  31116                       1
# 3851839  22466476          9  31116                       2
# 3851840  26613325          9  31116                       2
# 3851841  17386569          7  31409                       1
# 3851842  12698657          1  31409                       1
#
#          prioridad_hermano  prioridad_hijo_funcionario  prioridad_exalumno  \
# 0                        0                           0                   0
# 1                        0                           0                   0
# ...

# %%
df_postulaciones_final['AGNO'] = df_postulaciones_final['AGNO'].astype(int)
df_postulaciones_final.head(10)
# Out:
#     mrun  cod_nivel    rbd  preferencia_postulante  prioridad_hermano  \
# 0   3684          9     97                       1                  0
# 1   3684          9    108                       3                  0
# 2   3684          9    109                       4                  0
# 3   3684          9    134                       5                  0
# 4   3684          9  10901                       6                  0
# 5   3684          9  12504                       7                  0
# 6   3684          9  12518                       2                  0
# 7  40261         11     97                       4                  0
# 8  40261         11     97                       3                  0
# 9  40261         11    109                       2                  0
#
#    prioridad_hijo_funcionario  prioridad_exalumno  es_mujer  \
# 0                           0                   0         0
# 1                           0                   0         0
# ...

# %%
df_directorio.head(5)
# Out:
#    AGNO  RBD  DGV_RBD                                            NOM_RBD MRUN  \
# 0  2021   97        3          INST. COM. DE IQUIQUE BALDOMERO WOLNITZKY
# 1  2021  103        1          ESC.EDUC.GRAL.BAS.Y DES.ART.VIOLETA PARRA
# 2  2021  107        4             LICEO LIBERT. GRAL.BERNARDO OÂ´HIGGINS
# 3  2021  108        2           LICEO POLITEC. JOSE GUTIERREZ DE LA FUEN
# 4  2021  109        0  COLEGIO DEPORTIVO TEC. PROF. ELENA DUVAUCHELLE...
#
#   RUT_SOSTENEDOR  P_JURIDICA  COD_REG_RBD NOM_REG_RBD_A  COD_PRO_RBD  ...  \
# 0       70938800           1            1          TPCA           11  ...
# 1       70938800           1            1          TPCA           11  ...
# 2       70938800           1            1          TPCA           11  ...
# 3       70938800           1            1          TPCA           11  ...
# 4       70938800           1            1          TPCA           11  ...
#
#    ENS_08 ENS_09  ENS_10 ENS_11  MATRICULA  ESTADO_ESTAB  ORI_RELIGIOSA  \
# ...

# %%
# para cada nivel de enseñanza vamos a evaluar que los colegios a los cuales esten postulando los alumnos sean municipales o subvencionados, para evitar errores.
mask_1b = df_postulaciones_final['cod_nivel']==1
mask_2b = df_postulaciones_final['cod_nivel']==2
mask_3b = df_postulaciones_final['cod_nivel']==3
mask_4b = df_postulaciones_final['cod_nivel']==4
mask_5b = df_postulaciones_final['cod_nivel']==5
mask_6b = df_postulaciones_final['cod_nivel']==6
mask_7b = df_postulaciones_final['cod_nivel']==7
mask_8b = df_postulaciones_final['cod_nivel']==8
mask_1m = df_postulaciones_final['cod_nivel']==9
mask_2m = df_postulaciones_final['cod_nivel']==10
mask_3m = df_postulaciones_final['cod_nivel']==11
mask_4m = df_postulaciones_final['cod_nivel']==12

df_postulaciones_1b = df_postulaciones_final[mask_1b]
df_postulaciones_2b = df_postulaciones_final[mask_2b]
df_postulaciones_3b = df_postulaciones_final[mask_3b]
df_postulaciones_4b = df_postulaciones_final[mask_4b]
df_postulaciones_5b = df_postulaciones_final[mask_5b]
df_postulaciones_6b = df_postulaciones_final[mask_6b]
df_postulaciones_7b = df_postulaciones_final[mask_7b]
df_postulaciones_8b = df_postulaciones_final[mask_8b]
df_postulaciones_1m = df_postulaciones_final[mask_1m]
df_postulaciones_2m = df_postulaciones_final[mask_2m]
df_postulaciones_3m = df_postulaciones_final[mask_3m]
df_postulaciones_4m = df_postulaciones_final[mask_4m]

df_postulaciones_1b = df_postulaciones_1b.reset_index(drop=True)
df_postulaciones_2b = df_postulaciones_2b.reset_index(drop=True)
df_postulaciones_3b = df_postulaciones_3b.reset_index(drop=True)
df_postulaciones_4b = df_postulaciones_4b.reset_index(drop=True)
df_postulaciones_5b = df_postulaciones_5b.reset_index(drop=True)
df_postulaciones_6b = df_postulaciones_6b.reset_index(drop=True)
df_postulaciones_7b = df_postulaciones_7b.reset_index(drop=True)
df_postulaciones_8b = df_postulaciones_8b.reset_index(drop=True)
df_postulaciones_1m = df_postulaciones_1m.reset_index(drop=True)
df_postulaciones_2m = df_postulaciones_2m.reset_index(drop=True)
df_postulaciones_3m = df_postulaciones_3m.reset_index(drop=True)
df_postulaciones_4m = df_postulaciones_4m.reset_index(drop=True)

df_postulaciones_1b.columns = df_postulaciones_1b.columns.str.upper()
df_postulaciones_2b.columns = df_postulaciones_2b.columns.str.upper()
df_postulaciones_3b.columns = df_postulaciones_3b.columns.str.upper()
df_postulaciones_4b.columns = df_postulaciones_4b.columns.str.upper()
df_postulaciones_5b.columns = df_postulaciones_5b.columns.str.upper()
df_postulaciones_6b.columns = df_postulaciones_6b.columns.str.upper()
df_postulaciones_7b.columns = df_postulaciones_7b.columns.str.upper()
df_postulaciones_8b.columns = df_postulaciones_8b.columns.str.upper()
df_postulaciones_1m.columns = df_postulaciones_1m.columns.str.upper()
df_postulaciones_2m.columns = df_postulaciones_2m.columns.str.upper()
df_postulaciones_3m.columns = df_postulaciones_3m.columns.str.upper()
df_postulaciones_4m.columns = df_postulaciones_4m.columns.str.upper()

depe2_1b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_1b.RBD)])
depe2_2b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_2b.RBD)])
depe2_3b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_3b.RBD)])
depe2_4b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_4b.RBD)])
depe2_5b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_5b.RBD)])
depe2_6b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_6b.RBD)])
depe2_7b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_7b.RBD)])
depe2_8b = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_8b.RBD)])
depe2_1m = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_1m.RBD)])
depe2_2m = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_2m.RBD)])
depe2_3m = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_3m.RBD)])
depe2_4m = np.unique([np.array(df_directorio[df_directorio.RBD==rbd]['COD_DEPE2'])[0] for rbd in np.unique(df_postulaciones_4m.RBD)])

print('Primero basico',depe2_1b)
print('Segundo basico',depe2_2b)
print('Tercero basico',depe2_3b)
print('Cuarto  basico',depe2_4b)
print('Quinto  basico',depe2_5b)
print('Sexto   basico',depe2_6b)
print('Septimo basico',depe2_7b)
print('Octavo  basico',depe2_8b)
print('Primero  medio',depe2_1m)
print('Segundo  medio',depe2_2m)
print('Tercero  medio',depe2_3m)
print('Cuarto   medio',depe2_4m)
# Out:
# Primero basico [1 2]
# Segundo basico [1 2]
# Tercero basico [1 2]
# Cuarto  basico [1 2]
# Quinto  basico [1 2]
# Sexto   basico [1 2]
# Septimo basico [1 2]
# Octavo  basico [1 2]
# Primero  medio [1 2]
# Segundo  medio [1 2]
# Tercero  medio [1 2]
# Cuarto   medio [1 2]

# %% [markdown]
# Verificamos que en todos los casos anteriores los colegios que integran la lista de solucitudes del SAE, son municipales o particulares subvencionados.

# %%
# si quisieramos saber cuantos postulantes tenemos para cada uno de los cursos
print('Primero basico',np.unique(df_postulaciones_1b.MRUN).shape[0])
print('Segundo basico',np.unique(df_postulaciones_2b.MRUN).shape[0])
print('Tercero basico',np.unique(df_postulaciones_3b.MRUN).shape[0])
print('Cuarto  basico',np.unique(df_postulaciones_4b.MRUN).shape[0])
print('Quinto  basico',np.unique(df_postulaciones_5b.MRUN).shape[0])
print('Sexto   basico',np.unique(df_postulaciones_6b.MRUN).shape[0])
print('Septimo basico',np.unique(df_postulaciones_7b.MRUN).shape[0])
print('Octavo  basico',np.unique(df_postulaciones_8b.MRUN).shape[0])
print('Primero  medio',np.unique(df_postulaciones_1m.MRUN).shape[0])
print('Segundo  medio',np.unique(df_postulaciones_2m.MRUN).shape[0])
print('Tercero  medio',np.unique(df_postulaciones_3m.MRUN).shape[0])
print('Cuarto   medio',np.unique(df_postulaciones_4m.MRUN).shape[0])
# Out:
# Primero basico 243755
# Segundo basico 59092
# Tercero basico 52103
# Cuarto  basico 49028
# Quinto  basico 49604
# Sexto   basico 45972
# Septimo basico 121087
# Octavo  basico 45301
# Primero  medio 416761
# Segundo  medio 42040
# Tercero  medio 33561
# Cuarto   medio 9283

# %%
df_postulaciones_1b.head(10)
# Out:
#       MRUN  COD_NIVEL    RBD  PREFERENCIA_POSTULANTE  PRIORIDAD_HERMANO  \
# 0  6175675          1    107                       2                  0
# 1  6175675          1    110                       1                  0
# 2  6175675          1    133                       3                  0
# 3  6175675          1  12504                       5                  0
# 4  6175675          1  12518                       4                  0
# 5  7610377          1    107                      10                  0
# 6  7610377          1    110                       6                  0
# 7  7610377          1    112                       8                  0
# 8  7610377          1    129                       9                  0
# 9  7610377          1    133                       2                  0
#
#    PRIORIDAD_HIJO_FUNCIONARIO  PRIORIDAD_EXALUMNO  ES_MUJER  \
# 0                           0                   0         1
# ...

# %%
# juntamos las tabals de postulaciones con directorio para poder extraer la latitud y longitud de directorio
df_postulaciones_1b = df_postulaciones_1b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_2b = df_postulaciones_2b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_3b = df_postulaciones_3b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_4b = df_postulaciones_4b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_5b = df_postulaciones_5b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_6b = df_postulaciones_6b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_7b = df_postulaciones_7b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_8b = df_postulaciones_8b.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_1m = df_postulaciones_1m.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_2m = df_postulaciones_2m.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_3m = df_postulaciones_3m.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_4m = df_postulaciones_4m.merge(df_directorio[['RBD','LATITUD','LONGITUD']])
df_postulaciones_1b
# Out:
#             MRUN  COD_NIVEL    RBD  PREFERENCIA_POSTULANTE  PRIORIDAD_HERMANO  \
# 0        6175675          1    107                       2                  0
# 1        7610377          1    107                      10                  0
# 2       10817289          1    107                       3                  0
# 3       11942625          1    107                       3                  0
# 4       14318079          1    107                       4                  0
# ...          ...        ...    ...                     ...                ...
# 829724  15464916          1   4131                       1                  0
# 829725  11082396          1   4133                       1                  0
# 829726  21936658          1   4133                       1                  1
# 829727  18662930          1   4133                       1                  1
# 829728  22473173          1  12065                       1                  0
#
# ...

# %%
df_nombres  = pd.read_excel(path_directorio+'Nombres_Colegios_FIX/Nombres_Colegios_CLEAN.xlsx')

# %%
common_RBD = set(df_directorio_1oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_1oB.loc[df_directorio_1oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_2oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_2oB.loc[df_directorio_2oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_3oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_3oB.loc[df_directorio_3oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_4oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_4oB.loc[df_directorio_4oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_5oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_5oB.loc[df_directorio_5oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_6oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_6oB.loc[df_directorio_6oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_7oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_7oB.loc[df_directorio_7oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_8oB['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_8oB.loc[df_directorio_8oB['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_1oM['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_1oM.loc[df_directorio_1oM['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_2oM['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_2oM.loc[df_directorio_2oM['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_3oM['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_3oM.loc[df_directorio_3oM['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
common_RBD = set(df_directorio_4oM['RBD']).intersection(df_nombres['RBD'])
for rbd in common_RBD:
    df_directorio_4oM.loc[df_directorio_4oM['RBD'] == rbd, 'NOM_RBD'] = df_nombres.loc[df_nombres['RBD'] == rbd, 'NOM_RBD'].iloc[0]

# %%
df_directorio_1oB['PORC-MATR'] = (df_directorio_1oB['PROM-POST']/df_directorio_1oB.CALU)*100
df_directorio_2oB['PORC-MATR'] = (df_directorio_2oB['PROM-POST']/df_directorio_2oB.CALU)*100
df_directorio_3oB['PORC-MATR'] = (df_directorio_3oB['PROM-POST']/df_directorio_3oB.CALU)*100
df_directorio_4oB['PORC-MATR'] = (df_directorio_4oB['PROM-POST']/df_directorio_4oB.CALU)*100
df_directorio_5oB['PORC-MATR'] = (df_directorio_5oB['PROM-POST']/df_directorio_5oB.CALU)*100
df_directorio_6oB['PORC-MATR'] = (df_directorio_6oB['PROM-POST']/df_directorio_6oB.CALU)*100
df_directorio_7oB['PORC-MATR'] = (df_directorio_7oB['PROM-POST']/df_directorio_7oB.CALU)*100
df_directorio_8oB['PORC-MATR'] = (df_directorio_8oB['PROM-POST']/df_directorio_8oB.CALU)*100
df_directorio_1oM['PORC-MATR'] = (df_directorio_1oM['PROM-POST']/df_directorio_1oM.CALU)*100
df_directorio_2oM['PORC-MATR'] = (df_directorio_2oM['PROM-POST']/df_directorio_2oM.CALU)*100
df_directorio_3oM['PORC-MATR'] = (df_directorio_3oM['PROM-POST']/df_directorio_3oM.CALU)*100
df_directorio_4oM['PORC-MATR'] = (df_directorio_4oM['PROM-POST']/df_directorio_4oM.CALU)*100

# %%
df_directorio_1oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_1oB.csv',sep=';',index=False)
df_directorio_2oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_2oB.csv',sep=';',index=False)
df_directorio_3oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_3oB.csv',sep=';',index=False)
df_directorio_4oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_4oB.csv',sep=';',index=False)
df_directorio_5oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_5oB.csv',sep=';',index=False)
df_directorio_6oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_6oB.csv',sep=';',index=False)
df_directorio_7oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_7oB.csv',sep=';',index=False)
df_directorio_8oB.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_8oB.csv',sep=';',index=False)
df_directorio_1oM.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_1oM.csv',sep=';',index=False)
df_directorio_2oM.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_2oM.csv',sep=';',index=False)
df_directorio_3oM.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_3oM.csv',sep=';',index=False)
df_directorio_4oM.to_csv(path_directorio+'Directorio_Colegios/df_directorio_clean_final_4oM.csv',sep=';',index=False)
