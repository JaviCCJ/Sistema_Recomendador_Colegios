# %% [markdown]
# # Limpieza de datos CAPSTONE PROJECT

# %%
# librerias a utilizar para la limpieza de datos
import pandas as pd
import numpy as np


from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Limpieza de los datos de rendimiento

# %%
path_directorio_og = '/content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL'

path_directorio = []
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2004_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2005_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2006_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2007_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2008_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2009_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2010_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2011_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2012_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2013_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2014_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2015_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2016_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2017_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2018_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2019_PRIV_MRUN.csv')
path_directorio.append(path_directorio_og+'/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2020_PUB_MRUN.csv')

for path in path_directorio:
    print(path[:-4])
    df_MATRICULA = pd.read_csv(path,sep=';',low_memory=False,encoding="ISO-8859-1")
    df_MATRICULA.columns = df_MATRICULA.columns.str.strip().str.upper()
    if 'ANYO_PROCESO' in df_MATRICULA:
      df_MATRICULA.rename(columns = {'ANYO_PROCESO':'AÑO_PROCESO'}, inplace = True)
    elif'AÃO_PROCESO' in df_MATRICULA:
      df_MATRICULA.rename(columns = {'AÃO_PROCESO':'AÑO_PROCESO'}, inplace = True)
    df_MATRICULA.rename(columns = {'LUGAR_EN_LA_LISTA':'LUGAR'}, inplace = True)
    df_MATRICULA = df_MATRICULA[['MRUN','AÑO_PROCESO','CODIGO_CARRERA','NOMBRE_CARRERA','SIGLA_UNIVERSIDAD','PUNTAJE_PONDERADO','LUGAR']]
    df_MATRICULA.to_csv(path[:-4] + '_CLEAN_30042024.csv',sep=';',index=False)
# Out:
# /content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2004_PRIV_MRUN
# /content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2005_PRIV_MRUN
# /content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2006_PRIV_MRUN
# /content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2007_PRIV_MRUN
# /content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2008_PRIV_MRUN
# /content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2009_PRIV_MRUN
# /content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/Data DEMRE/Matrícula 2004-2020/D_MATRICULA_PSU_2010_PRIV_MRUN
# ...

# %%
df_MATRICULA
# Out:
#            MRUN  AÑO_PROCESO  CODIGO_CARRERA  \
# 0       8163861         2020           16068
# 1       9677220         2020           16017
# 2       1802668         2020           18046
# 3       8425779         2020           16035
# 4      20155991         2020           41071
# ...         ...          ...             ...
# 98542  26105295         2020           50528
# 98543  26105394         2020           14072
# 98544  26105270         2020           15170
# 98545  26105307         2020           44001
# 98546  26105158         2020           24087
#
#                                           NOMBRE_CARRERA SIGLA_UNIVERSIDAD  \
# 0                            INGENIERÃA EN AGRONEGOCIOS             USACH
# 1                     INGENIERÃA DE EJECUCIÃN EN MINAS             USACH
# 2                                   INGENIERIA COMERCIAL               UCN
# 3                                  INGENIERÃA COMERCIAL             USACH
# ...
