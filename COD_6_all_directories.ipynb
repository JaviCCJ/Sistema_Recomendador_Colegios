# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#leemos la base de datos del directorio}
path_directorio_og = '/content/drive/MyDrive/DOCUMENTOS_TESIS_JAVIERA_JORQUERA/CODIGOS_FINAL/'

path_directorio = []
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_1oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_2oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_3oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_4oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_5oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_6oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_7oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_8oB.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_1oM.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_2oM.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_3oM.csv')
path_directorio.append(path_directorio_og+'Directorio_Colegios/df_directorio_clean_final_4oM.csv')

# %%
for i in range(0,12):
    df_directorio_aux = pd.read_csv(path_directorio[i],sep=';',low_memory=False,encoding="ISO-8859-1")
    print(df_directorio_aux.shape)
    df_directorio_aux['GEN_H'] = 0
    df_directorio_aux['GEN_M'] = 0
    df_directorio_aux.loc[df_directorio_aux['CHOM'] > 0, 'GEN_H'] = 1
    df_directorio_aux.loc[df_directorio_aux['CMUJ'] > 0, 'GEN_M'] = 1
    df_directorio_aux['COD_NIVEL'] = str(i+1)
    df_directorio_aux.fillna(0, inplace=True)
    df_directorio_aux['E_NIVEL'] = df_directorio_aux.apply(lambda row: 0 if (row[['PROM', 'ASIS', 'APRB', 'NOND', 'CALU', 'CHOM', 'CMUJ']] == 0).any() else str(i+1), axis=1)
    if i != 0:
        df_directorio_all = pd.concat([df_directorio_all, df_directorio_aux])
        df_directorio_all.reset_index(inplace=True, drop = True)
    else:
        df_directorio_all = df_directorio_aux.copy()
    del df_directorio_aux


df_directorio_all.to_csv(path_directorio_og+'Directorio_Colegios/df_directorio_all.csv',sep=';',index=False)
print(df_directorio_all.shape)
df_directorio_all
# Out:
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (8367, 32)
# (100404, 36)
#           RBD  DGV_RBD                                            NOM_RBD  \
# 0          97        3          INST. COM. DE IQUIQUE BALDOMERO WOLNITZKY
# 1         103        1          ESC.EDUC.GRAL.BAS.Y DES.ART.VIOLETA PARRA
# 2         107        4             LICEO LIBERT. GRAL.BERNARDO OÂ´HIGGINS
# 3         108        2           LICEO POLITEC. JOSE GUTIERREZ DE LA FUEN
# 4         109        0  COLEGIO DEPORTIVO TEC. PROF. ELENA DUVAUCHELLE...
# ...       ...      ...                                                ...
# 100399  31090        5               COMPLEJO EDUCACIONAL VALLE DEL ITATA
# 100400  31108        1  ESCUELA ESPECIAL DE LENGUAJE Y COLEGIO BÃSICO...
# 100401  31116        2     COLEGIO BICENTENARIO ENRIQUE SALINAS BUSCOVICH
# ...
